# %%
import os

try:
    snakemake
except NameError:
    from snakemk_util import load_rule_args
    snakemake = load_rule_args(
        snakefile = os.getcwd() + '/../Snakefile',
        rule_name = 'literature',
        root=os.getcwd() + "/.."
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-55a0c991fe33> in <module>
#       3 try:
# ----> 4     snakemake
#       5 except NameError:
#
# NameError: name 'snakemake' is not defined
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-55a0c991fe33> in <module>
#       8         snakefile = os.getcwd() + '/../Snakefile',
#       9         rule_name = 'literature',
# ---> 10         root=os.getcwd() + "/.."
#      11 )
#
# /opt/modules/i12g/anaconda/envs/als/lib/python3.7/site-packages/snakemk_util/rule_args.py in load_rule_args(snakefile, rule_name, default_wildcards, change_dir, create_dir, root)
#      88         # load workflow
#      89         workflow = Workflow(snakefile=snakefile)
# ---> 90         workflow.include(snakefile)
#      91         # get rule
#      92         rule = workflow.get_rule(rule_name)
#
# /opt/modules/i12g/anaconda/envs/als/lib/python3.7/site-packages/snakemake/workflow.py in include(self, snakefile, overwrite_first_rule, print_compilation, overwrite_shellcmd)
#    1116         self.linemaps[snakefile] = linemap
#    1117
# -> 1118         exec(compile(code, snakefile, "exec"), self.globals)
#    1119
#    1120         if not overwrite_first_rule:
#
# /opt/modules/i12g/anaconda/envs/als/lib/python3.7/site-packages/snakemake/workflow.py in <module>
# ----> 1 configfile: "configs/config.yaml"
#       2
#       3
#       4 chroms = [
#       5     'chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7',
#
# /opt/modules/i12g/anaconda/envs/als/lib/python3.7/site-packages/snakemake/workflow.py in configfile(self, fp)
#    1173         if not self.modifier.skip_configfile:
#    1174             self.configfiles.append(fp)
# -> 1175             c = snakemake.io.load_configfile(fp)
#    1176             update_config(config, c)
#    1177             update_config(config, self.overwrite_config)
#
# /opt/modules/i12g/anaconda/envs/als/lib/python3.7/site-packages/snakemake/io.py in load_configfile(configpath)
#    1601 def load_configfile(configpath):
#    1602     "Loads a JSON or YAML configfile as a dict, then checks that it's a dict."
# -> 1603     config = _load_configfile(configpath)
#    1604     if not isinstance(config, dict):
#    1605         raise WorkflowError(
#
# /opt/modules/i12g/anaconda/envs/als/lib/python3.7/site-packages/snakemake/io.py in _load_configfile(configpath_or_obj, filetype)
#    1566
#    1567     if isinstance(configpath_or_obj, str) or isinstance(configpath_or_obj, Path):
# -> 1568         obj = open(configpath_or_obj)
#    1569     else:
#    1570         obj = configpath_or_obj
#
# FileNotFoundError: [Errno 2] No such file or directory: 'configs/config.yaml'

# %%
genes = {
    'Abbertant RNA metabolism':[
        'SETX', 'FUS', 'ANG', 'TARDBP', 'ELP3', 'TAF15', 'EWSR1', 
        'ATXN2', 'HNRNPA1', 'C9orf72', 'HNRNPA2B1', 'MATR3'
    ],
    'Impaired DNA repair': ['NEK1', 'C21orf2', 'SPG11', 'FUS'],
    'Nuclear export': ['C9orf72'],
    'Impaired protein homeostatis': ['SIGMAR1', 'CHMP2B', 'C9orf72', 'SQSTM1', 
                                     'UBQLN2', 'SOD1', 'ALS2', 'VAPB', 'OPTN', 'TBK1'],
    'Oxidative stress': ['SOD1', 'ALS2', 'TARDBP'],
    'Mitochondrial dysfunction': ['SOD1', 'CHCHD10', 'TARDBP'],
    'Dysregulated vesicle trasnport': ['SOD1', 'ALS2','FIG4', 'VAPB', 'OPTN', 'UNC13A', 'CHMP2B']
}

# %%
wgs = {'Farhan 2016': ['ALS2',
  'ANG',
  'ARHGEF28',
  'ATXN2',
  'CENPV',
  'CHMP2B',
  'DAO',
  'DCTN1',
  'FIG4 ',
  'FUS',
  'HNRNPA1',
  'HNRNPA2B1',
  'MAPT',
  'NEFH',
  'OPTN',
  'PFN1',
  'PRPH',
  'SETX',
  'SIGMAR1',
  'SOD1',
  'TARDBP',
  'UBQLN2',
  'UNC13A',
  'VAPB',
  'VCP',
  'APOE'],
 'Goldstein 2016': ['OPTN'],
 'Kim 2016': ['ALS2',
  'ANG',
  'DAO',
  'FIG4 ',
  'FUS',
  'GRN',
  'MAPTOPTN',
  'SETX',
  'SIGMAR1',
  'SOD1',
  'SPG11',
  'SQSTM1',
  'TAF15',
  'RARDBP',
  'UBQLN2',
  'VAPB',
  'VCP'],
 'Kim 2017': ['TBK1'],
 'Lamp 2018': ['ALS',
  'ANG',
  'BSCL2',
  'CHMP2B',
  'DCTN1',
  'ERBB4',
  'FIG4 ',
  'FUS',
  'GRN',
  'HNRNPA1',
  'MAPT',
  'MATR3',
  'OPTN',
  'PFN1',
  'PSEN1',
  'PSEN2',
  'SETX',
  'SOD1',
  'SPG11',
  'TARDBP',
  'UBQLN2',
  'VAPB',
  'VCP'],
 'Leblond 2016': ['MATR3'],
 'Liu 2014': ['ALS',
  'ANG',
  'CHMP2B',
  'DAO',
  'DCTN1',
  'FIG4 ',
  'FUS',
  'OPTN',
  'PFN1',
  'SETX',
  'SIGMAR1',
  'SOD1',
  'SPG11',
  'SQSTM1',
  'TARDBP',
  'UBQLN2',
  'VAPB',
  'VCP'],
 'Marangi 2017': ['ANG',
  'ATXN2',
  'CHCHD10',
  'CHMP2B',
  'CHRNA4',
  'DAO',
  'DCTN1',
  'EPHA4',
  'EWSR1',
  'FIG4 ',
  'FUS',
  'GLE1',
  'GRN',
  'HNRNPA1',
  'HNRNPA2B1',
  'MAPT3',
  'MATR3',
  'NIPA1',
  'OPTN',
  'PFN1',
  'SETX',
  'SIGMAR1',
  'SOD1',
  'SQSTM1',
  'SS18L1',
  'TAF15',
  'TARDBP',
  'TBK1',
  'TUBA4A',
  'UBQLN2',
  'VAPB',
  'VCP'],
 'Morgan 2017': ['ALS2',
  'ANG',
  'CHMP2B',
  'DAO',
  'DCTN1',
  'FIG4 ',
  'FUS',
  'NEFH',
  'OPTN',
  'PFN1',
  'PON1',
  'PON2',
  'PON3',
  'PRPH',
  'SETX',
  'SOD1',
  'SQSTM1',
  'TARDBP',
  'TREM2',
  'UBQLN2',
  'VAPB',
  'VCP',
  'VEGF'],
 'Nakamura 2016': ['ALS2',
  'ANG',
  'ATXN2',
  'CHMP2B',
  'DAO',
  'DCTN1',
  'EWSR1',
  'FIG4 ',
  'FUS',
  'GRN',
  'NEFH',
  'OPTN',
  'PFN1',
  'PRPH',
  'RNF19A',
  'SETX',
  'SIGMAR1',
  'SOD1',
  'SPG11',
  'SQSTM1',
  'TAF15',
  'TARDBP',
  'TFG',
  'UBQLN2',
  'VAPB',
  'VCP',
  'ZNF512B'],
 'Narain 2018': ['ANG',
  'CHMP2B',
  'DAO',
  'DCTN1',
  'ELP3',
  'ERBB4',
  'FIG4 ',
  'FUS',
  'LUM',
  'MATR3',
  'OPTN',
  'PFN1',
  'PON1',
  'PON2',
  'PON3',
  'PRPH',
  'SETX',
  'SOD1',
  'SPAST',
  'SQDTM1',
  'TAF15',
  'TARDBP',
  'UBQLN2',
  'VAPB',
  'VCP'],
 'Nishiyama 2017': ['ALS2',
  'ANG',
  'ATXN2',
  'CHMP2B',
  'DAO',
  'DCTN1',
  'FIG4',
  'FUS',
  'NEFH',
  'OPTN',
  'PFN1',
  'PRPH',
  'SETX',
  'SIGMAR1',
  'SOD1',
  'SPG11',
  'TAF15',
  'TARDBP',
  'UBQLN2',
  'VAPB',
  'VCP'],
 'Tripolszki 2017': ['FUS', 'SETX', 'c9orf72'],
 'Turk 2017': ['CAPZA1',
  'CAPZB',
  'CCDC53',
  'FAM21C',
  'KIAA1033',
  'KIAA0196',
  'VCP',
  'WASH1']}

# %%
import pandas as pd

df_hardiman = pd.DataFrame([
    {'gene_name': g, 'pathway': p, 'cite': 'Hardiman 2017'}
    for p, genes in genes.items()
    for g in genes
])

# %%
df_wgs = pd.DataFrame([
    {'gene_name': g, 'cite': k}
    for k, genes in wgs.items()
    for g in genes
])

# %%
df_wgs.to_csv(snakemake.output['wgs'], index=False)

# %%
df_hardiman.to_csv(snakemake.output['nature_review'], index=False)
